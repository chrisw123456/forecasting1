# %%
#pip install pymssql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymssql
#   Downloading pymssql-2.2.1-cp36-cp36m-manylinux2014_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 1.6 MB/s eta 0:00:01
# Installing collected packages: pymssql
# Successfully installed pymssql-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymssql
from sqlalchemy import create_engine
from sqlalchemy.engine import Engine
from pymssql import Connection
import pandas as pd

# %%
# sql server engine func
def get_engine(username:str, password:str, server:str, database:str) -> Engine:
    """ connects to MS SQL Server
    Args:
        username (str)
        password (str)
        server (str)
        database (str)
    Returns:
        Engine
    """
    conn_string = f"mssql+pymssql://{username}:{password}@{server}/{database}"
    engine = create_engine(conn_string)
    return engine

# get connection
def get_cnx(username:str, password:str, server:str, database:str) -> Connection:
    """ enables querying MS SQL Server
    Args:
        username (str): [description]
        password (str): [description]
        server (str): [description]
        database (str): [description]
    Returns:
        pymssql.Connection: [description]
    """
    cnx = pymssql.connect(user=username, password=password,
                          host=server, database=database)
    return cnx

# read table to pandas
def read_sql_table(table_name:str, cnx:pymssql.Connection) -> pd.DataFrame:
    """reads sql table into pandas df
    Args:
        table_name (str): table name in SQL DB
        cnx (pymssql.Connection): connection object used to read query
    Returns:
        pd.DataFrame: [description]
    """
    sql_table = pd.read_sql(sql=f"SELECT * FROM {table_name}",
                            con=cnx)

    return sql_table

# write df tp sql server
def write_df_to_sql(
        expID: str, new_df: pd.DataFrame, table_name: str, cnx: Connection, engine: Engine,
        replace_exist_table=False):
    """[summary]
    #columns_to_consider: List[str]
    Args:
        new_df (pd.DataFrame): name of df to be written to sql db
        table_name (str): name of table to write to 
        cnx (Connection): used to read sql tables
        engine (Engine): used to write to sql db 
        columns_to_consider (List[str]): columns to be examined when checking for duplicates
        init (bool, optional): indicates if tables need 
        to be created for the first time. Defaults to False.
    """
    # add expID
    new_df.insert(0,'ExpID',str(expID))

    # conert all columns to string
    new_df=new_df.applymap(str)

    # convert all columns named with (min) to _min
    new_df.columns=[i.replace('(min)','_min') if '(min)' in i else i for i in new_df.columns]
    
    #write new_df to sql server
    if replace_exist_table:
        if_exists='replace'
    
    else:  
        if_exists='append'

    new_df.to_sql(name=table_name,con=engine, index=False, if_exists=if_exists)

# %%
engine = get_engine("transam1","Pass@0@0!","usodcvsql0255", "NAO_PMO_Analytics")

# %%
connection = get_cnx("transam1","Pass@0@0!","usodcvsql0255", "NAO_PMO_Analytics")

# %%
data = read_sql_table("zzz_Forecast_Input",connection)

# %%
data.to_csv("input.csv")

# %%
exportsql = pd.read_csv("exportsql.csv")

# %%
write_df_to_sql("zzzchris", exportsql, "zzz_chris_jupyter", connection ,  engine,
        replace_exist_table=False)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# src/pymssql/_pymssql.pyx in pymssql._pymssql.Cursor.execute()
#
# src/pymssql/_mssql.pyx in pymssql._mssql.MSSQLConnection.execute_query()
#
# src/pymssql/_mssql.pyx in pymssql._mssql.MSSQLConnection.execute_query()
#
# src/pymssql/_mssql.pyx in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# src/pymssql/_mssql.pyx in pymssql._mssql.check_cancel_and_raise()
#
# src/pymssql/_mssql.pyx in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (511, b'Cannot create a row of size 10908 which is greater than the allowable maximum row size of 8060.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#
# src/pymssql/_pymssql.pyx in pymssql._pymssql.Cursor.executemany()
#
# src/pymssql/_pymssql.pyx in pymssql._pymssql.Cursor.execute()
#
# OperationalError: (511, b'Cannot create a row of size 10908 which is greater than the allowable maximum row size of 8060.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-8eff1fe368b0> in <module>
#       1 write_df_to_sql("zzzchris", exportsql, "zzz_chris_jupyter", connection ,  engine,
# ----> 2        replace_exist_table=False)
#
# <ipython-input-2-989f7d88d7d1> in write_df_to_sql(expID, new_df, table_name, cnx, engine, replace_exist_table)
#      74         if_exists='append'
#      75
# ---> 76     new_df.to_sql(name=table_name,con=engine, index=False, if_exists=if_exists)
#      77
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# /usr/local/anaconda3/envs/py3.6/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     588
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
#
# src/pymssql/_pymssql.pyx in pymssql._pymssql.Cursor.executemany()
#
# src/pymssql/_pymssql.pyx in pymssql._pymssql.Cursor.execute()
#
# OperationalError: (pymssql._pymssql.OperationalError) (511, b'Cannot create a row of size 10908 which is greater than the allowable maximum row size of 8060.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n')
# [SQL: INSERT INTO zzz_chris_jupyter ([ExpID], [Date], [Scenario], [Product], [Sub.Product], [Volumes], [c1_AAA_ets], [c1_AAN_ets], c1_add_holtlineartrend, c1_add_holtlineartrenddamp, [c1_ANA_ets], c1_autoregressive_integratedmovingaverage, c1_autoregressive_integratedmovingaverage_1, c1_autoregressive_integratedmovingaverage_2, c1_autoregressive_integratedmovingaverage_3, c1_autoregressive_integratedmovingaverage_4, c1_autoregressive_integratedmovingaverage_5, c1_boxcoxtransform_armaerrors_trend_seasonal, c1_cubicspline1, c1_cubicspline2, c1_double_holt_additive, c1_dynamicharmonicregression, c1_linearmodel_seasontrend, c1_linearmodel_trend, [c1_MAA_ets], [c1_MAM_ets], [c1_MAN_ets], [c1_MMM_ets], [c1_MMN_ets], [c1_MNA_ets], [c1_MNM_ets], c1_sarima1, c1_sarima10, c1_sarima100, c1_sarima101, c1_sarima102, c1_sarima103, c1_sarima104, c1_sarima105, c1_sarima106, c1_sarima107, c1_sarima108, c1_sarima109, c1_sarima11, c1_sarima110, c1_sarima111, c1_sarima112, c1_sarima113, c1_sarima115, c1_sarima116, c1_sarima117, c1_sarima118, c1_sarima119, c1_sarima12, c1_sarima120, c1_sarima121, c1_sarima122, c1_sarima123, c1_sarima124, c1_sarima125, c1_sarima126, c1_sarima127, c1_sarima128, c1_sarima129, c1_sarima13, c1_sarima130, c1_sarima131, c1_sarima132, c1_sarima133, c1_sarima135, c1_sarima136, c1_sarima137, c1_sarima138, c1_sarima139, c1_sarima140, c1_sarima15, c1_sarima16, c1_sarima17, c1_sarima18, c1_sarima19, c1_sarima2, c1_sarima20, c1_sarima21, c1_sarima22, c1_sarima23, c1_sarima24, c1_sarima25, c1_sarima26, c1_sarima27, c1_sarima28, c1_sarima29, c1_sarima3, c1_sarima30, c1_sarima31, c1_sarima32, c1_sarima33, c1_sarima35, c1_sarima36, c1_sarima37, c1_sarima38, c1_sarima39, c1_sarima4, c1_sarima40, c1_sarima41, c1_sarima42, c1_sarima43, c1_sarima44, c1_sarima45, c1_sarima46, c1_sarima47, c1_sarima48, c1_sarima49, c1_sarima5, c1_sarima50, c1_sarima51, c1_sarima52, c1_sarima53, c1_sarima55, c1_sarima56, c1_sarima57, c1_sarima58, c1_sarima59, c1_sarima6, c1_sarima60, c1_sarima61, c1_sarima62, c1_sarima63, c1_sarima64, c1_sarima65, c1_sarima66, c1_sarima67, c1_sarima68, c1_sarima69, c1_sarima7, c1_sarima70, c1_sarima71, c1_sarima72, c1_sarima73, c1_sarima75, c1_sarima76, c1_sarima77, c1_sarima78, c1_sarima79, c1_sarima8, c1_sarima80, c1_sarima81, c1_sarima82, c1_sarima83, c1_sarima84, c1_sarima85, c1_sarima86, c1_sarima87, c1_sarima88, c1_sarima89, c1_sarima9, c1_sarima90, c1_sarima91, c1_sarima92, c1_sarima93, c1_sarima95, c1_sarima96, c1_sarima97, c1_sarima98, c1_sarima99, c1_simple_expo_smooth0, c1_triple_holtwinters_additive0, c1_triple_holtwinters_additive1, c1_triple_holtwinters_additive10, c1_triple_holtwinters_additive100, c1_triple_holtwinters_additive101, c1_triple_holtwinters_additive102, c1_triple_holtwinters_additive103, c1_triple_holtwinters_additive104, c1_triple_holtwinters_additive105, c1_triple_holtwinters_additive106, c1_triple_holtwinters_additive107, c1_triple_holtwinters_additive108, c1_triple_holtwinters_additive109, c1_triple_holtwinters_additive11, c1_triple_holtwinters_additive110, c1_triple_holtwinters_additive111, c1_triple_holtwinters_additive112, c1_triple_holtwinters_additive113, c1_triple_holtwinters_additive114, c1_triple_holtwinters_additive115, c1_triple_holtwinters_additive116, c1_triple_holtwinters_additive117, c1_triple_holtwinters_additive118, c1_triple_holtwinters_additive119, c1_triple_holtwinters_additive12, c1_triple_holtwinters_additive120, c1_triple_holtwinters_additive121, c1_triple_holtwinters_additive122, c1_triple_holtwinters_additive123, c1_triple_holtwinters_additive124, c1_triple_holtwinters_additive125, c1_triple_holtwinters_additive126, c1_triple_holtwinters_additive127, c1_triple_holtwinters_additive128, c1_triple_holtwinters_additive129, c1_triple_holtwinters_additive13, c1_triple_holtwinters_additive130, c1_triple_holtwinters_additive131, c1_triple_holtwinters_additive132, c1_triple_holtwinters_additive133, c1_triple_holtwinters_additive134, c1_triple_holtwinters_additive135, c1_trip ...
# [parameters: ({'ExpID': 'zzzchris', 'Date': '2019-01-01', 'Scenario': 'Field Ops - Mass Markets - Test 7/7/2021', 'Product': 'EAST', 'Sub.Product': 'FL_TX', 'Volumes': '52567.0', 'c1_AAA_ets': '0.0', 'c1_AAN_ets': '0.0', 'c1_add_holtlineartrend': '0.0', 'c1_add_holtlineartrenddamp': '0.0', 'c1_ANA_ets': '0.0', 'c1_autoregressive_integratedmovingaverage': '0.0', 'c1_autoregressive_integratedmovingaverage_1': '0.0', 'c1_autoregressive_integratedmovingaverage_2': '0.0', 'c1_autoregressive_integratedmovingaverage_3': '0.0', 'c1_autoregressive_integratedmovingaverage_4': '0.0', 'c1_autoregressive_integratedmovingaverage_5': '0.0', 'c1_boxcoxtransform_armaerrors_trend_seasonal': '0.0', 'c1_cubicspline1': '0.0', 'c1_cubicspline2': '0.0', 'c1_double_holt_additive': '0.0', 'c1_dynamicharmonicregression': '0.0', 'c1_linearmodel_seasontrend': '0.0', 'c1_linearmodel_trend': '0.0', 'c1_MAA_ets': '0.0', 'c1_MAM_ets': '0.0', 'c1_MAN_ets': '0.0', 'c1_MMM_ets': '0.0', 'c1_MMN_ets': '0.0', 'c1_MNA_ets': '0.0', 'c1_MNM_ets': '0.0', 'c1_sarima1': '0', 'c1_sarima10': '0.0', 'c1_sarima100': '0.0', 'c1_sarima101': '0.0', 'c1_sarima102': '0.0', 'c1_sarima103': '0.0', 'c1_sarima104': '0.0', 'c1_sarima105': '0.0', 'c1_sarima106': '0.0', 'c1_sarima107': '0.0', 'c1_sarima108': '0.0', 'c1_sarima109': '0.0', 'c1_sarima11': '0.0', 'c1_sarima110': '0.0', 'c1_sarima111': '0.0', 'c1_sarima112': '0.0', 'c1_sarima113': '0.0', 'c1_sarima115': '0.0', 'c1_sarima116': '0.0', 'c1_sarima117': '0.0', 'c1_sarima118': '0.0', 'c1_sarima119': '0.0', 'c1_sarima12': '0.0', 'c1_sarima120': '0.0', 'c1_sarima121': '0.0', 'c1_sarima122': '0.0', 'c1_sarima123': '0.0', 'c1_sarima124': '0.0', 'c1_sarima125': '0.0', 'c1_sarima126': '0.0', 'c1_sarima127': '0.0', 'c1_sarima128': '0.0', 'c1_sarima129': '0.0', 'c1_sarima13': '0.0', 'c1_sarima130': '0.0', 'c1_sarima131': '0.0', 'c1_sarima132': '0.0', 'c1_sarima133': '0.0', 'c1_sarima135': '0.0', 'c1_sarima136': '0.0', 'c1_sarima137': '0.0', 'c1_sarima138': '0.0', 'c1_sarima139': '0.0', 'c1_sarima140': '0.0', 'c1_sarima15': '0.0', 'c1_sarima16': '0.0', 'c1_sarima17': '0.0', 'c1_sarima18': '0.0', 'c1_sarima19': '0.0', 'c1_sarima2': '0.0', 'c1_sarima20': '0.0', 'c1_sarima21': '0.0', 'c1_sarima22': '0.0', 'c1_sarima23': '0.0', 'c1_sarima24': '0.0', 'c1_sarima25': '0.0', 'c1_sarima26': '0.0', 'c1_sarima27': '0.0', 'c1_sarima28': '0.0', 'c1_sarima29': '0.0', 'c1_sarima3': '0.0', 'c1_sarima30': '0.0', 'c1_sarima31': '0.0', 'c1_sarima32': '0.0', 'c1_sarima33': '0.0', 'c1_sarima35': '0.0', 'c1_sarima36': '0.0', 'c1_sarima37': '0.0', 'c1_sarima38': '0.0', 'c1_sarima39': '0.0', 'c1_sarima4': '0.0', 'c1_sarima40': '0.0', 'c1_sarima41': '0.0', 'c1_sarima42': '0.0', 'c1_sarima43': '0.0', 'c1_sarima44': '0.0', 'c1_sarima45': '0.0', 'c1_sarima46': '0.0', 'c1_sarima47': '0.0', 'c1_sarima48': '0.0', 'c1_sarima49': '0.0', 'c1_sarima5': '0.0', 'c1_sarima50': '0.0', 'c1_sarima51': '0.0', 'c1_sarima52': '0.0', 'c1_sarima53': '0.0', 'c1_sarima55': '0.0', 'c1_sarima56': '0.0', 'c1_sarima57': '0.0', 'c1_sarima58': '0.0', 'c1_sarima59': '0.0', 'c1_sarima6': '0.0', 'c1_sarima60': '0.0', 'c1_sarima61': '0.0', 'c1_sarima62': '0.0', 'c1_sarima63': '0.0', 'c1_sarima64': '0.0', 'c1_sarima65': '0.0', 'c1_sarima66': '0.0', 'c1_sarima67': '0.0', 'c1_sarima68': '0.0', 'c1_sarima69': '0.0', 'c1_sarima7': '0.0', 'c1_sarima70': '0.0', 'c1_sarima71': '0.0', 'c1_sarima72': '0.0', 'c1_sarima73': '0.0', 'c1_sarima75': '0.0', 'c1_sarima76': '0.0', 'c1_sarima77': '0.0', 'c1_sarima78': '0.0', 'c1_sarima79': '0.0', 'c1_sarima8': '0.0', 'c1_sarima80': '0.0', 'c1_sarima81': '0.0', 'c1_sarima82': '0.0', 'c1_sarima83': '0.0', 'c1_sarima84': '0.0', 'c1_sarima85': '0.0', 'c1_sarima86': '0.0', 'c1_sarima87': '0.0', 'c1_sarima88': '0.0', 'c1_sarima89': '0.0', 'c1_sarima9': '0.0', 'c1_sarima90': '0.0', 'c1_sarima91': '0.0', 'c1_sarima92': '0.0', 'c1_sarima93': '0.0', 'c1_sarima95': '0.0', 'c1_sarima96': '0.0', 'c1_sarima97': '0.0', 'c1_sarima98': '0.0', 'c1_sarima99': '0.0', 'c1_simple_expo_s ...
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
